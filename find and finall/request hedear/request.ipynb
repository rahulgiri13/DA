# %%
import requests as rq

# %%
url = "https://www.samsung.com/in/offer/online/samsung-fest/television-soundbar/"

# %%
rResp = rq . get(url)

# %%
rResp
# Out:
# <Response [200]>

# %%
rResp.text
# Out:
# '<!DOCTYPE html>\r\n\r\n<html lang="en-IN">\r\n    \r\n    <head>\r\n\t<!-- PWA - manifest\r\n\t<link rel="manifest" href="/etc.clientlibs/samsung/clientlibs/consumer/global/clientlib-common/resources/pwa/manifest/in.json">\r\n\t -->\r\n\t<!-- PWA - Browser Compatible\r\n\t<script async src="/etc.clientlibs/samsung/clientlibs/consumer/global/clientlib-common/resources/pwa/js/pwacompat.js"></script>\r\n\t -->\r\n\t<!-- <meta name="theme-color" content="#0c4da2"> -->\r\n\t<!-- Add to home screen for Safari on iOS -->\r\n    <!-- <meta name="apple-mobile-web-app-capable" content="yes">\r\n    <meta name="apple-mobile-web-app-status-bar-style" content="black">\r\n    <meta name="apple-mobile-web-app-title" content="Samsung Shop">\r\n    <link rel="apple-touch-icon" href="/etc.clientlibs/samsung/clientlibs/consumer/global/clientlib-common/resources/pwa/icon/pwa_icon_192x192.png"> -->\r\n    <!-- Add to home screen for Windows -->\r\n    <!-- <meta name="msapplication-TileImage" content="/
# ...

# %%
type(rResp.headers)
# Out:
# requests.structures.CaseInsensitiveDict

# %%
rheader = rResp.headers
print(rheader)
# Out:
# {'Content-Type': 'text/html; charset=UTF-8', 'Vary': 'Accept-Encoding', 'X-Frame-Options': 'SAMEORIGIN', 'Last-Modified': 'Tue, 04 Jun 2024 11:29:57 GMT', 'ETag': 'W/"8eb36-61a0ec5049c70"', 'Strict-Transport-Security': 'max-age=31536000', 'X-XSS-Protection': '0', 'X-Akamai-Transformed': '9 - 0 pmb=mRUM,3', 'Content-Encoding': 'gzip', 'Date': 'Tue, 04 Jun 2024 15:55:46 GMT', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive, Transfer-Encoding', 'Set-Cookie': 'country_region=CA-ON; path=/; domain=.samsung.com, s_fpid=356be5ee-c2a6-49a4-aee2-f14e5466611c; expires=Thu, 04-Jun-2026 15:55:46 GMT; path=/; domain=.samsung.com; secure; HttpOnly, country_codes=in; path=/; domain=.samsung.com, device_type=pc; path=/; domain=.samsung.com', 'Server-Timing': 'cdn-cache; desc=HIT, edge; dur=284, origin; dur=0, ak_p; desc="1717516545736_825014092_145844723_28407_25539_67_112_-";dur=1'}

# %%
print(f'date = {rheader['date']}')
# Out:
# date = Tue, 04 Jun 2024 15:55:46 GMT

# %%
userAgent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"

# %%
checkheader = rq.get(url,headers={'User-Agent' : userAgent})

# %%
print(checkheader)
# Out:
# <Response [200]>

# %%
checkheader.request.headers
# Out:
# {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
